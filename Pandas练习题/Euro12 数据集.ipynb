# %% [markdown]
# # Euro12 数据集

# %% [markdown]
# ### Step 1. 导入库

# %%
import numpy as np
import pandas as pd
import ssl
ssl._create_default_https_context = ssl._create_unverified_context # 全局取消证书验证

# %% [markdown]
# ### Step 2. 导入数据，并命名为euro12： [address](https://raw.githubusercontent.com/guipsamora/pandas_exercises/master/02_Filtering_%26_Sorting/Euro12/Euro_2012_stats_TEAM.csv).

# %%
url = 'https://raw.githubusercontent.com/guipsamora/pandas_exercises/master/02_Filtering_%26_Sorting/Euro12/Euro_2012_stats_TEAM.csv'
euro12 = pd.read_table(url, sep=',')
euro12.head()
# Out:
#              Team  Goals  Shots on target  Shots off target Shooting Accuracy  \
# 0         Croatia      4               13                12             51.9%
# 1  Czech Republic      4               13                18             41.9%
# 2         Denmark      4               10                10             50.0%
# 3         England      5               11                18             50.0%
# 4          France      3               22                24             37.9%
#
#   % Goals-to-shots  Total shots (inc. Blocked)  Hit Woodwork  Penalty goals  \
# 0            16.0%                          32             0              0
# 1            12.9%                          39             0              0
# 2            20.0%                          27             1              0
# 3            17.2%                          40             0              0
# 4             6.5%                          65             1              0
#
# ...

# %% [markdown]
# ### Step 3. 只选择Goals列.

# %%
euro12['Goals']
# Out:
# 0      4
# 1      4
# 2      4
# 3      5
# 4      3
# 5     10
# 6      5
# 7      6
# 8      2
# 9      2
# 10     6
# 11     1
# 12     5
# 13    12
# 14     5
# 15     2
# Name: Goals, dtype: int64

# %% [markdown]
# ### Step 4.  选择Team, Yellow Cards, Red Cards 列，并添加到一个新的DataFrame里，discipline

# %%
discipline = euro12[['Team', 'Yellow Cards', 'Red Cards']]
discipline
# Out:
#                    Team  Yellow Cards  Red Cards
# 0               Croatia             9          0
# 1        Czech Republic             7          0
# 2               Denmark             4          0
# 3               England             5          0
# 4                France             6          0
# 5               Germany             4          0
# 6                Greece             9          1
# 7                 Italy            16          0
# 8           Netherlands             5          0
# 9                Poland             7          1
# 10             Portugal            12          0
# 11  Republic of Ireland             6          1
# 12               Russia             6          0
# 13                Spain            11          0
# 14               Sweden             7          0
# 15              Ukraine             5          0

# %% [markdown]
# ### Step 5. 选择进球数超过 6 的行

# %%
euro12[euro12.Goals>6]
# Out:
#        Team  Goals  Shots on target  Shots off target Shooting Accuracy  \
# 5   Germany     10               32                32             47.8%
# 13    Spain     12               42                33             55.9%
#
#    % Goals-to-shots  Total shots (inc. Blocked)  Hit Woodwork  Penalty goals  \
# 5             15.6%                          80             2              1
# 13            16.0%                         100             0              1
#
#     Penalties not scored      ...       Saves made  Saves-to-shots ratio  \
# 5                      0      ...               10                 62.6%
# 13                     0      ...               15                 93.8%
#
#     Fouls Won Fouls Conceded  Offsides  Yellow Cards  Red Cards  Subs on  \
# 5          63             49        12             4          0       15
# 13        102             83        19            11          0       17
#
#     Subs off  Players Used
# 5         15            17
# ...

# %% [markdown]
# ### Step 6. 选择Team以“G”开头的行

# %%
euro12[euro12.Team.apply(lambda x: x[0]=='G')]

euro12[euro12.Team.str.startswith('G')]
# Out:
#       Team  Goals  Shots on target  Shots off target Shooting Accuracy  \
# 5  Germany     10               32                32             47.8%
# 6   Greece      5                8                18             30.7%
#
#   % Goals-to-shots  Total shots (inc. Blocked)  Hit Woodwork  Penalty goals  \
# 5            15.6%                          80             2              1
# 6            19.2%                          32             1              1
#
#    Penalties not scored      ...       Saves made  Saves-to-shots ratio  \
# 5                     0      ...               10                 62.6%
# 6                     1      ...               13                 65.1%
#
#    Fouls Won Fouls Conceded  Offsides  Yellow Cards  Red Cards  Subs on  \
# 5         63             49        12             4          0       15
# 6         67             48        12             9          1       12
#
#    Subs off  Players Used
# 5        15            17
# ...

# %% [markdown]
# ### Step 7. 前3行

# %%
euro12.iloc[:3]
# Out:
#              Team  Goals  Shots on target  Shots off target Shooting Accuracy  \
# 0         Croatia      4               13                12             51.9%
# 1  Czech Republic      4               13                18             41.9%
# 2         Denmark      4               10                10             50.0%
#
#   % Goals-to-shots  Total shots (inc. Blocked)  Hit Woodwork  Penalty goals  \
# 0            16.0%                          32             0              0
# 1            12.9%                          39             0              0
# 2            20.0%                          27             1              0
#
#    Penalties not scored      ...       Saves made  Saves-to-shots ratio  \
# 0                     0      ...               13                 81.3%
# 1                     0      ...                9                 60.1%
# 2                     0      ...               10                 66.7%
#
# ...

# %% [markdown]
# ### Step 8. 最后3列.

# %%
euro12.iloc[:, -3:]
# Out:
#     Subs on  Subs off  Players Used
# 0         9         9            16
# 1        11        11            19
# 2         7         7            15
# 3        11        11            16
# 4        11        11            19
# 5        15        15            17
# 6        12        12            20
# 7        18        18            19
# 8         7         7            15
# 9         7         7            17
# 10       14        14            16
# 11       10        10            17
# 12        7         7            16
# 13       17        17            18
# 14        9         9            18
# 15        9         9            18

# %% [markdown]
# ### Step 9. 选择3到7行，3到6列

# %%
euro12.iloc[2: 7, 2: 6]
# Out:
#    Shots on target  Shots off target Shooting Accuracy % Goals-to-shots
# 2               10                10             50.0%            20.0%
# 3               11                18             50.0%            17.2%
# 4               22                24             37.9%             6.5%
# 5               32                32             47.8%            15.6%
# 6                8                18             30.7%            19.2%

# %% [markdown]
# ### Step 11. England, Italy, Russia的Shooting Accuracy

# %%
euro12.loc[euro12.Team.isin(['England', 'Italy', 'Russia']), ['Team', 'Shooting Accuracy']] # England, Italy and Russia不是索引
# Out:
#        Team Shooting Accuracy
# 3   England             50.0%
# 7     Italy             43.0%
# 12   Russia             22.5%

# %% [markdown]
# ### Step 12. 将Team设置为索引，并选择England, Italy, Russia的Shooting Accuracy

# %%
euro12.set_index('Team', inplace=True)
euro12.loc[['England', 'Italy', 'Russia'], ['Shooting Accuracy']]
